# %% [markdown]
# 1.2 Изучите стоимости недвижимости

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
df = pd.read_csv('kc_house_data.csv', sep = ',')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
plt.hist(df['price'])
plt.title('Распределение стоимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество домов')
# Out:
# Text(0, 0.5, 'Количество домов')

# %% [markdown]
# 1.3 Изучите распределение квадратуры жилой площади

# %%
plt.hist(df['sqft_living'])
plt.title('Распределение квадратуры жилой площади')
plt.xlabel('Жилая площадь')
plt.ylabel('количество домов')
# Out:
# Text(0, 0.5, 'количество домов')

# %% [markdown]
# 2.1.4 Изучите распределение года постройки

# %%
plt.hist(df['yr_built'])
plt.title('Распределение квадратуры жилой площади')
plt.xlabel('Год постройки')
plt.ylabel('Количетсво домов')
# Out:
# Text(0, 0.5, 'Количетсво домов')

# %% [markdown]
# 2.1 Изучите распределение домов от наличия вида на набережную

# %%
plt.pie(df['waterfront'].value_counts().values, autopct = '%1.1f%%', labels = df['waterfront'].value_counts().index);

# %% [markdown]
# 2.2 Изучите распределение этажей домов

# %%
floors_qnt = df['floors'].value_counts()

index_values = floors_qnt.values
index_names = floors_qnt.index

plt.bar(index_names, index_values)
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('количество домов')
plt.xticks(rotation = 90);

# %% [markdown]
# 2.2 Изучите распределение состояния домов

# %%
condition_grade = df['condition'].value_counts()

index_values = condition_grade.values
index_names = condition_grade.index

plt.bar(index_names, index_values)
plt.title('Распределение состояния домов')
plt.xlabel('Оценка состояния домов')
plt.ylabel('количество домов')
plt.xticks(rotation = 90);

# %% [markdown]
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
import seaborn as sns
corr_matrix = df.corr()
corr_matrix = np.round(corr_matrix, 1)
corr_matrix[np.abs(corr_matrix) < 0.3] = 0
corr_matrix
sns.heatmap(corr_matrix, annot = True, linewidths= 0.5, cmap= 'coolwarm');
# Out:
# C:\Users\админ\AppData\Local\Temp\ipykernel_8588\2789539014.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df['price'], y=df['grade'].astype('str'), whis=1.5)
plt.xlabel('стоимость')
plt.ylabel('оценка');

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['price'], df['grade'])
plt.title('Зависимость дома от оценки')
plt.xlabel('стоимость')
plt.ylabel('оценка');

# %% [markdown]
# чем выше оценка дома, тем он дороже

# %%
sns.jointplot(x=df['sqft_living'], y=df['price'], kind='reg')

# %% [markdown]
# чем больше жилая площадь, тем дороже дом
